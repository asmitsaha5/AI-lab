# %%
def dls_366(graph_366, current_node_366, goal_node_366, depth_limit_366, path_366):
    path_366.append(current_node_366)

    if current_node_366 == goal_node_366:
        return True

    if depth_limit_366 == 0:
        path_366.pop()
        return False

    for neighbor_366 in graph_366[current_node_366]:
        if dls_366(graph_366, neighbor_366, goal_node_366, depth_limit_366 - 1, path_366):
            return True

    path_366.pop()
    return False

graph_366 = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G': []
}

start_node_366 = 'A'

goal_node_366 = input("Enter the goal node: ")
depth_limit_366 = int(input("Enter depth limit: "))

path_366 = []

found_366 = dls_366(graph_366, start_node_366, goal_node_366, depth_limit_366, path_366)

if found_366:
    print("\nGoal found!")
    print("DLS Path:", " -> ".join(path_366))
else:
    print("\nGoal not found within depth limit")
# Out:
# Goal found!
# DLS Path: A -> B -> E -> G

# %%
def dls_366(graph_366, current_node_366, goal_node_366, depth_limit_366, path_366):
    path_366.append(current_node_366)

    if current_node_366 == goal_node_366:
        return True

    if depth_limit_366 == 0:
        path_366.pop()
        return False

    for neighbor_366 in graph_366[current_node_366]:
        if dls_366(graph_366, neighbor_366, goal_node_366, depth_limit_366 - 1, path_366):
            return True

    path_366.pop()
    return False


def iddfs_366(graph_366, start_node_366, goal_node_366, max_depth_366):
    for depth_366 in range(max_depth_366 + 1):
        path_366 = []

        if dls_366(graph_366, start_node_366, goal_node_366, depth_366, path_366):
            return path_366
    return None


graph_366 = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G': []
}

start_node_366 = 'A'

goal_node_366 = input("Enter the goal node: ")
max_depth_366 = int(input("Enter maximum depth limit: "))

result_path_366 = iddfs_366(graph_366, start_node_366, goal_node_366, max_depth_366)

if result_path_366:
    print("\nGoal found!")
    print("IDDFS Path:", " -> ".join(result_path_366))
else:
    print("\nGoal not found within maximum depth")
# Out:
# Goal found!
# IDDFS Path: A -> B -> E -> G
